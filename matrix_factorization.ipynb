# %%
"""
Colby Wise
Matrix Factorization

Factorizers a N x M user:item matrix into
U: N x r and V: r X M matrices where:

- U - User : feature matrix
- V - Movie: feature matrix

Calculates mean squared error (MSE) and
mean reciprocal rank (MMR) on test data
after the training data decomposition
"""

# %%
import pandas as pd
import numpy as np
import time
import pickle
import math

from preprocessing import *
from model_evaluation import *

# %%
"""
Class MatrixFactorize takes train and test data then
factors the training data in U,V matrix decompositions.
Using U,V it then predicts movie ratings on the test
data returning the MSE and MRR on test data
"""
class MatrixFactorize(object):
    
    """
    Initialization
    @param:
        train - pandas dataframe of training data
        test - pandas dataframe of test data
        lr  - learning rate
        r - features to learn
        epoch - epochs to run training 
        lambd - regularization rate (lambda)

    """
    def __init__(self, train, test, lr, r, iters, lambd):
        self.lr = lr
        self.features = r
        self.iters = iters
        self.lambd = lambd
        self.train = train
        self.test = test
        
        all_data = pd.concat([train, test])
        self.n_items = len(all_data['movieId'].unique())
        self.n_users = len(all_data['userId'].unique())
        print("Number of users:", self.n_users)
        print("Number of movies:", self.n_items)  
        
        self.U = np.random.randn(self.n_users, self.features)
        self.V = np.random.randn(self.features, self.n_items)
        
        self.loss_record = {"train": [], "test": [], "epoch": [],
                            "r": self.features,"lr" : self.lr}
    """
    Updates loss dictionary that captures training/test
    MSE during training 
    @param:
        test_mse - MSE from test data
        train_mse - MSE from train data
        epoch - current epoch of training
    @Return:
        None
    """
    def record_loss(self, test_mse, train_mse, epoch):
        self.loss_record["train"].append(train_mse)
        self.loss_record["test"].append(test_mse)
        self.loss_record["epoch"].append(epoch)
    
    """
    Predict rating using current U, V matrices
    @param:
        test_sample - random sample from test data
        U - User matrix
        V - Movie matrix
        show - default(False), prints subset of predict values
    @Return:
        mse - mean squared error for test sample
    """ 
    def predict(self, test_sample, U, V, show=False):
        preds = []
        loss = 0
        print("Running test validation...")
        cntr = 1
        for row in test_sample.itertuples():
            user, movie, rating = row[2], row[3], row[4]
            pred = np.dot(U[user,:], np.transpose(V[:,movie]) )
            preds.append(pred) 
            
            if not (cntr % 10**5) and show:
                print("u: {} \t m: {} \t r: {} \t r_hat: {}".format(user, movie, rating, pred))
                
            err = rating - pred
            loss += err**2
            cntr += 1
        MSE = (loss/len(preds))
        return MSE
    
    """
    Punny name ... saves pickle objects during training phase
    @param:
        out - data structure (dict, etc) to save
        fname - filename
    @Return:
        None
    """  
    def god_save_the_queen(self, out, fname):
        with open(fname, "wb") as f:
            pickle.dump(out, f)
        return None
        
    """
    Uses train and test data to learn U,V matrix decomposition
    """     
    def factorizeMatrix(self):
        print("Factorizing...")
        print("=> learning rate: {}, epochs: {}, r: {}".format(self.lr, self.iters, self.features))
              
        epoch_start = time.time()
        for epoch in range(1,self.iters+1):
            print("\nStarting iteration {}...".format(epoch))
            self.lr = self.lr * .995 # Hacky annealing
            
            best_test_MSE = 50
            cntr = 1
            _s = time.time()
            for row in self.train.itertuples():
                user, movie, rating = row[2], row[3], row[4]
                err = rating - np.dot( self.U[user,:], np.transpose(self.V[:,movie]) )
                train_MSE = err ** 2
                dV = self.lr * (err * 2 * self.U[user,:] - self.lambd * self.V[:,movie])
                dU = self.lr * (err * 2 * self.V[:,movie] - self.lambd * self.U[user,:])
                self.V[:,movie] = self.V[:,movie] + dV
                self.U[user,:] = self.U[user,:] + dU
                cntr += 1
                                
                # Periodically Print Progress 
                if not (cntr % 10**5):
                    _e = time.time()
                    print( "\n {} min runtime to process {:,} rows...\n".format(int((_e-_s)//60), cntr) )
                    test_sample = self.test.sample(frac=0.05)
                    U, V = self.U, self.V
                    test_MSE = calc_MSE(test_sample, U, V, show=False) 
                    self.record_loss(test_MSE, train_MSE, epoch)
                    print( "Train MSE: {0:0.4f}, Test MSE: {1:0.4f}".format(train_MSE, test_MSE))
                    
                    # Periodically Check Test MSE
                    if test_MSE <= best_test_MSE:
                        best_test_MSE = test_MSE
                        u_outfile = "U_mat:_r={}_lambda={}_epoch={}.pkl".format(self.features, self.lambd, epoch)
                        v_outfile = "V_mat:_r={}_lambda={}_epoch={}.pkl".format(self.features, self.lambd, epoch)
                        loss_file = "loss:{:.3f}_r={}_lambda={}_epoch={}.pkl".format(test_MSE, self.features, self.lambd, epoch)
                        self.god_save_the_queen(self.U, u_outfile)
                        self.god_save_the_queen(self.V, v_outfile)
                        self.god_save_the_queen(self.loss_record, loss_file)
            # Track epoch runtime
            epoch_end = time.time()
            print("\n Epoch {} runtime: {} min".format(epoch, int((epoch_end-epoch_start)//60)))

        MRR = calc_MRR(self.test, self.U, self.V)
        with open('MRR.txt', 'w') as f:
            f.write("log:_MRR={:.3f}:_r={}_lambda={}".format(MRR, self.features, self.lambd))

        return self.U, self.V, self.loss_record

# %%
def update_movieId(movie):
    return item_toKey[movie]

def update_userId(user):
    return user_toKey[user]

# %%
train_file = 'ml-20m/train.csv'
test_file = 'ml-20m/test.csv'

train = get_data(train_file)
test = get_data(test_file)
all_data = pd.concat([train, test])
key_toUser, user_toKey = get_user_dicts(all_data)
key_toItem, item_toKey = get_item_dicts(all_data)

train['userId'] = train['userId'].apply(update_userId)
train['movieId'] = train['movieId'].apply(update_movieId)
test['userId'] = test['userId'].apply(update_userId)
test['movieId'] = test['movieId'].apply(update_movieId)
# Out:
# Number of users:  138493
# Number of items:  26744

# %%
lr = .01
r = 40
epoch = 2
lamda = .2

MF = MatrixFactorize(train, test, lr, r, epoch, lamda)
U, V, loss_record = MF.factorizeMatrix()
# Out:
# Number of users: 138493
# Number of movies: 26744
# Factorizing...
# => learning rate: 0.01, epochs: 1, r: 40
#
# Starting iteration 1...
#
#  0 min runtime to process 100,000 rows...
#
# Running test validation...
# Train MSE: 297.3694, Test MSE: 38.7706
#
#  0 min runtime to process 200,000 rows...
#
# Running test validation...
# Train MSE: 0.0607, Test MSE: 33.1755
#
#  0 min runtime to process 300,000 rows...
#
# Running test validation...
# Train MSE: 0.0216, Test MSE: 30.1558
#
#  0 min runtime to process 400,000 rows...
#
# Running test validation...
# Train MSE: 6.5000, Test MSE: 28.1908
#
#  0 min runtime to process 500,000 rows...
#
# Running test validation...
# Train MSE: 3.3417, Test MSE: 26.7850
#
#  0 min runtime to process 600,000 rows...
#
# Running test validation...
# Train MSE: 0.5040, Test MSE: 25.8193
#
#  0 min runtime to process 700,000 rows...
#
# Running test validation...
# Train MSE: 0.0391, Test MSE: 24.9449
#
#  0 min runtime to process 800,000 rows...
#
# Running test validation...
# Train MSE: 0.1751, Test MSE: 24.2598
#
#  0 min runtime to process 900,000 rows...
#
# Running test validation...
# Train MSE: 0.1634, Test MSE: 23.6215
#
#  0 min runtime to process 1,000,000 rows...
#
# Running test validation...
# Train MSE: 4.8426, Test MSE: 23.1580
#
#  1 min runtime to process 1,100,000 rows...
#
# Running test validation...
# Train MSE: 1.6419, Test MSE: 22.6347
#
#  1 min runtime to process 1,200,000 rows...
#
# Running test validation...
# Train MSE: 12.1017, Test MSE: 22.1795
#
#  1 min runtime to process 1,300,000 rows...
#
# Running test validation...
# Train MSE: 0.1392, Test MSE: 21.7744
#
#  1 min runtime to process 1,400,000 rows...
#
# Running test validation...
# Train MSE: 3.9849, Test MSE: 21.5117
#
#  1 min runtime to process 1,500,000 rows...
#
# Running test validation...
# Train MSE: 0.3581, Test MSE: 21.0199
#
#  1 min runtime to process 1,600,000 rows...
#
# Running test validation...
# Train MSE: 15.9148, Test MSE: 20.7772
#
#  1 min runtime to process 1,700,000 rows...
#
# Running test validation...
# Train MSE: 0.1771, Test MSE: 20.4546
#
#  1 min runtime to process 1,800,000 rows...
#
# Running test validation...
# Train MSE: 39.1241, Test MSE: 20.0847
#
#  1 min runtime to process 1,900,000 rows...
#
# Running test validation...
# Train MSE: 24.4069, Test MSE: 19.8334
#
#  1 min runtime to process 2,000,000 rows...
#
# Running test validation...
# Train MSE: 0.1630, Test MSE: 19.5097
#
#  2 min runtime to process 2,100,000 rows...
#
# Running test validation...
# Train MSE: 1.1901, Test MSE: 19.2284
#
#  2 min runtime to process 2,200,000 rows...
#
# Running test validation...
# Train MSE: 0.6821, Test MSE: 19.0654
#
#  2 min runtime to process 2,300,000 rows...
#
# Running test validation...
# Train MSE: 5.8158, Test MSE: 18.8262
#
#  2 min runtime to process 2,400,000 rows...
#
# Running test validation...
# Train MSE: 0.0619, Test MSE: 18.5928
#
#  2 min runtime to process 2,500,000 rows...
#
# Running test validation...
# Train MSE: 0.0373, Test MSE: 18.2957
#
#  2 min runtime to process 2,600,000 rows...
#
# Running test validation...
# Train MSE: 1.7768, Test MSE: 18.0133
#
#  2 min runtime to process 2,700,000 rows...
#
# Running test validation...
# Train MSE: 1.9821, Test MSE: 17.6650
#
#  2 min runtime to process 2,800,000 rows...
#
# Running test validation...
# Train MSE: 6.8188, Test MSE: 17.5647
#
#  2 min runtime to process 2,900,000 rows...
#
# Running test validation...
# Train MSE: 2.4139, Test MSE: 17.3958
#
#  2 min runtime to process 3,000,000 rows...
#
# Running test validation...
# Train MSE: 2.2290, Test MSE: 17.1798
#
#  2 min runtime to process 3,100,000 rows...
#
# Running test validation...
# Train MSE: 0.0004, Test MSE: 16.8558
#
#  3 min runtime to process 3,200,000 rows...
#
# Running test validation...
# Train MSE: 6.0495, Test MSE: 16.5683
#
#  3 min runtime to process 3,300,000 rows...
#
# Running test validation...
# Train MSE: 0.1548, Test MSE: 16.3226
#
#  3 min runtime to process 3,400,000 rows...
#
# Running test validation...
# Train MSE: 2.2886, Test MSE: 16.1667
#
#  3 min runtime to process 3,500,000 rows...
#
# Running test validation...
# Train MSE: 2.0285, Test MSE: 15.9075
#
#  3 min runtime to process 3,600,000 rows...
#
# Running test validation...
# Train MSE: 0.0061, Test MSE: 15.6325
#
#  3 min runtime to process 3,700,000 rows...
#
# Running test validation...
# Train MSE: 1.7453, Test MSE: 15.5270
#
#  3 min runtime to process 3,800,000 rows...
#
# Running test validation...
# Train MSE: 11.1250, Test MSE: 15.3026
#
#  3 min runtime to process 3,900,000 rows...
#
# Running test validation...
# Train MSE: 77.9260, Test MSE: 15.0814
#
#  3 min runtime to process 4,000,000 rows...
#
# Running test validation...
# Train MSE: 1.2365, Test MSE: 14.7737
#
#  3 min runtime to process 4,100,000 rows...
#
# Running test validation...
# Train MSE: 0.1703, Test MSE: 14.6162
#
#  4 min runtime to process 4,200,000 rows...
#
# Running test validation...
# Train MSE: 0.5853, Test MSE: 14.5014
#
#  4 min runtime to process 4,300,000 rows...
#
# Running test validation...
# Train MSE: 8.8799, Test MSE: 14.2138
#
#  4 min runtime to process 4,400,000 rows...
#
# Running test validation...
# Train MSE: 3.1625, Test MSE: 14.0451
#
#  4 min runtime to process 4,500,000 rows...
#
# Running test validation...
# Train MSE: 1.2585, Test MSE: 13.6629
#
#  4 min runtime to process 4,600,000 rows...
#
# Running test validation...
# Train MSE: 1.0545, Test MSE: 13.5988
#
#  4 min runtime to process 4,700,000 rows...
#
# Running test validation...
# Train MSE: 1.7003, Test MSE: 13.3587
#
#  4 min runtime to process 4,800,000 rows...
#
# Running test validation...
# Train MSE: 0.0910, Test MSE: 13.1737
#
#  4 min runtime to process 4,900,000 rows...
#
# Running test validation...
# Train MSE: 0.5766, Test MSE: 12.8669
#
#  4 min runtime to process 5,000,000 rows...
#
# Running test validation...
# Train MSE: 28.2633, Test MSE: 12.7425
#
#  4 min runtime to process 5,100,000 rows...
#
# Running test validation...
# Train MSE: 1.0722, Test MSE: 12.5004
#
#  4 min runtime to process 5,200,000 rows...
#
# Running test validation...
# Train MSE: 0.0204, Test MSE: 12.2281
#
#  5 min runtime to process 5,300,000 rows...
#
# Running test validation...
# Train MSE: 3.4828, Test MSE: 12.0634
#
#  5 min runtime to process 5,400,000 rows...
#
# Running test validation...
# Train MSE: 31.2920, Test MSE: 11.8506
#
#  5 min runtime to process 5,500,000 rows...
#
# Running test validation...
# Train MSE: 2.4466, Test MSE: 11.5872
#
#  5 min runtime to process 5,600,000 rows...
#
# Running test validation...
# Train MSE: 5.5640, Test MSE: 11.4675
#
#  5 min runtime to process 5,700,000 rows...
#
# Running test validation...
# Train MSE: 12.7571, Test MSE: 11.1441
#
#  5 min runtime to process 5,800,000 rows...
#
# Running test validation...
# Train MSE: 33.3441, Test MSE: 10.9540
#
#  5 min runtime to process 5,900,000 rows...
#
# Running test validation...
# Train MSE: 0.5905, Test MSE: 10.7503
#
#  5 min runtime to process 6,000,000 rows...
#
# Running test validation...
# Train MSE: 3.7769, Test MSE: 10.4826
#
#  5 min runtime to process 6,100,000 rows...
#
# Running test validation...
# Train MSE: 0.0303, Test MSE: 10.3512
#
#  5 min runtime to process 6,200,000 rows...
#
# Running test validation...
# Train MSE: 0.0343, Test MSE: 10.0722
#
#  5 min runtime to process 6,300,000 rows...
#
# Running test validation...
# Train MSE: 0.1207, Test MSE: 9.8770
#
#  6 min runtime to process 6,400,000 rows...
#
# Running test validation...
# Train MSE: 0.1588, Test MSE: 9.7094
#
#  6 min runtime to process 6,500,000 rows...
#
# Running test validation...
# Train MSE: 0.0120, Test MSE: 9.5299
#
#  6 min runtime to process 6,600,000 rows...
#
# Running test validation...
# Train MSE: 0.7678, Test MSE: 9.2941
#
#  6 min runtime to process 6,700,000 rows...
#
# Running test validation...
# Train MSE: 0.0176, Test MSE: 9.1040
#
#  6 min runtime to process 6,800,000 rows...
#
# Running test validation...
# Train MSE: 8.3392, Test MSE: 8.8816
#
#  6 min runtime to process 6,900,000 rows...
#
# Running test validation...
# Train MSE: 4.0719, Test MSE: 8.7009
#
#  6 min runtime to process 7,000,000 rows...
#
# Running test validation...
# Train MSE: 1.5318, Test MSE: 8.4598
#
#  6 min runtime to process 7,100,000 rows...
#
# Running test validation...
# Train MSE: 4.5500, Test MSE: 8.1761
#
#  6 min runtime to process 7,200,000 rows...
#
# Running test validation...
# Train MSE: 0.0433, Test MSE: 7.9970
#
#  6 min runtime to process 7,300,000 rows...
#
# Running test validation...
# Train MSE: 4.5613, Test MSE: 7.8523
#
#  6 min runtime to process 7,400,000 rows...
#
# Running test validation...
# Train MSE: 0.2315, Test MSE: 7.6243
#
#  6 min runtime to process 7,500,000 rows...
#
# Running test validation...
# Train MSE: 4.9540, Test MSE: 7.4033
#
#  6 min runtime to process 7,600,000 rows...
#
# Running test validation...
# Train MSE: 0.3626, Test MSE: 7.2722
#
#  7 min runtime to process 7,700,000 rows...
#
# Running test validation...
# Train MSE: 4.2855, Test MSE: 7.0410
#
#  7 min runtime to process 7,800,000 rows...
#
# Running test validation...
# Train MSE: 9.2242, Test MSE: 6.7756
#
#  7 min runtime to process 7,900,000 rows...
#
# Running test validation...
# Train MSE: 0.2739, Test MSE: 6.5953
#
#  7 min runtime to process 8,000,000 rows...
#
# Running test validation...
# Train MSE: 1.2328, Test MSE: 6.4042
#
#  7 min runtime to process 8,100,000 rows...
#
# Running test validation...
# Train MSE: 0.9429, Test MSE: 6.2110
#
#  7 min runtime to process 8,200,000 rows...
#
# Running test validation...
# Train MSE: 0.1640, Test MSE: 5.9877
#
#  7 min runtime to process 8,300,000 rows...
#
# Running test validation...
# Train MSE: 3.0421, Test MSE: 5.7689
#
#  7 min runtime to process 8,400,000 rows...
#
# Running test validation...
# Train MSE: 1.4379, Test MSE: 5.6268
#
#  7 min runtime to process 8,500,000 rows...
#
# Running test validation...
# Train MSE: 7.4102, Test MSE: 5.3470
#
#  7 min runtime to process 8,600,000 rows...
#
# Running test validation...
# Train MSE: 0.7138, Test MSE: 5.1005
#
#  8 min runtime to process 8,700,000 rows...
#
# Running test validation...
# Train MSE: 1.4414, Test MSE: 4.9502
#
#  8 min runtime to process 8,800,000 rows...
#
# Running test validation...
# Train MSE: 0.1364, Test MSE: 4.7210
#
#  8 min runtime to process 8,900,000 rows...
#
# Running test validation...
# Train MSE: 2.3864, Test MSE: 4.5626
#
#  8 min runtime to process 9,000,000 rows...
#
# Running test validation...
# Train MSE: 0.0467, Test MSE: 4.3286
#
#  8 min runtime to process 9,100,000 rows...
#
# Running test validation...
# Train MSE: 0.1166, Test MSE: 4.1759
#
#  8 min runtime to process 9,200,000 rows...
#
# Running test validation...
# Train MSE: 2.8383, Test MSE: 3.9869
#
#  8 min runtime to process 9,300,000 rows...
#
# Running test validation...
# Train MSE: 0.3604, Test MSE: 3.7402
#
#  8 min runtime to process 9,400,000 rows...
#
# Running test validation...
# Train MSE: 4.4553, Test MSE: 3.5308
#
#  8 min runtime to process 9,500,000 rows...
#
# Running test validation...
# Train MSE: 4.9881, Test MSE: 3.2861
#
#  8 min runtime to process 9,600,000 rows...
#
# Running test validation...
# Train MSE: 38.4788, Test MSE: 3.1282
#
#  8 min runtime to process 9,700,000 rows...
#
# Running test validation...
# Train MSE: 2.5075, Test MSE: 2.9069
#
#  9 min runtime to process 9,800,000 rows...
#
# Running test validation...
# Train MSE: 1.7834, Test MSE: 2.7192
#
#  9 min runtime to process 9,900,000 rows...
#
# Running test validation...
# Train MSE: 2.4576, Test MSE: 2.4789
#
#  Epoch 1 runtime: 9 min
# Percent of rows removed given predictions < 3.0: 0.00%

# %%
def calc_MRR(df, U, V):
    start = time.time()
    MRR = []
    preds = []
    for row in df.itertuples():
        user, movie = row[2], row[3]
        u_vec, v_vec = U[user,:], V[:,movie]
        preds.append( predict_rating(u_vec, v_vec, rnd=True) )
        
    df['pred'] = pd.Series(preds)
    _s1 = len(df)
    df = df.loc[ df['pred'] >= 3.0 ]
    _s2 = len(df)
    print("Percent of rows removed given predictions < 3.0: {0:0.2f}%".format((_s1-_s2)//_s1))
    Q_length = len(df)
    df.sort_values(by=['userId','pred'], ascending=False)

    for user in df['userId'].unique():
        user_data = df.loc[ df['userId'] == user ]
        if len(user_data) > 0:
            rankings = user_data.index[ user_data['rating'] == user_data['pred'] ].tolist()
            if rankings:
                rank = rankings[0] + 1 # To account for 0 indexing
                print(rank)
                MRR.append( 1/rank )  
    print("sum:", sum(MRR))
    print("MRR:", sum(MRR)/Q_length)
    MRR = (sum(MRR)/Q_length) - 1 # Remove index adjustment
    print("MRR Calculation Runtime: {} min".format( int((time.time()-start)//60) ))
    print("Model MRR: ", MRR)
    return MRR

# %%
print( calc_MSE(MF.test,U,V) )

# %%
def properties(cls):   
    return [i for i in cls.__dict__.keys() if i[:1] != '_']

properties = props(MF)
print(properties)

# %%
V = pickle.load( open( "V_mat:_r=40_lambda=0.01_epoch=10.pkl", "rb" ) )
U = pickle.load( open( "U_mat:_r=40_lambda=0.01_epoch=10.pkl", "rb" ) )
print("U Shape:", U.shape)
print("V Shape:", V.shape)
# Out:
# (138493, 40)
# (40, 26744)

# %%
loss_file1 = "loss:1.1454883390569282_r=40_lambda=0.2_epoch=10.pkl"
loss_file2 = "loss:1.1104220640763836_r=40_lambda=0.01_epoch=10.pkl"
loss_file3 = "loss:0.8906265173171293_r=100_lambda=0.5_epoch=7.pkl" #epoch 7 ugh
loss_file4 = "loss:0.9162400916571781_r=10_lambda=0.001_epoch=10.pkl"
loss_file5 = "loss:1.2031739446700522_r=50_lambda=0.01_epoch=10.pkl"

# %%
def print_loss_data(fname, comma=True):
    losses = pickle.load( open( fname, "rb" ) )
    print("Train MSE    |   Test MSE")
    for tr,te in zip(losses['train'],losses['test']):
        if not comma:
            print("train: {0:0.4f} | test: {1:0.4f}".format(tr,te))
        else:
            print("{0:0.4f} , {1:0.4f}".format(tr,te))
        
def save_losses_to_csv(fname1,fname2):
    losses = pickle.load( open( fname1, "rb" ) )
    s_tr = pd.Series(losses['train'], name='train_MSE')
    s_te = pd.Series(losses['test'], name='test_MSE')
    L = pd.concat([s_tr, s_te], axis=1)
    L.to_csv(fname2)
    print("file saved as:",str(fname2))

# %%
losses = pickle.load( open( "loss:1.1454883390569282_r=40_lambda=0.2_epoch=10.pkl", "rb" ) )

# %%
print_loss_data(loss_file5,comma=True)
# Out:
# 106.8566 , 45.4117
# 18.1185 , 38.2210
# 7.8139 , 34.4534
# 4.8712 , 31.9924
# 3.9118 , 30.3133
# 26.8501 , 28.8412
# 21.8917 , 27.7958
# 2.1857 , 26.9774
# 0.5036 , 26.1042
# 10.5526 , 25.5807
# 2.2719 , 24.8030
# 2.6374 , 24.3189
# 2.1423 , 23.6883
# 11.9064 , 23.3008
# 5.9790 , 22.8418
# 8.7703 , 22.5621
# 0.0007 , 22.1266
# 13.6362 , 21.8406
# 1.2341 , 21.4222
# 6.4090 , 21.2024
# 10.7787 , 20.8501
# 0.4129 , 20.5569
# 1.7994 , 20.3474
# 0.3126 , 19.9337
# 0.3098 , 19.5916
# 3.3441 , 19.2762
# 1.3273 , 19.1348
# 6.7526 , 18.8508
# 11.9996 , 18.6238
# 3.5682 , 18.3730
# 3.4326 , 18.0634
# 61.4089 , 17.6856
# 4.0440 , 17.4580
# 4.9226 , 17.3143
# 0.2257 , 17.0361
# 0.0037 , 1.2441
# 0.7191 , 1.2321
# 0.0748 , 1.2368
# 0.0064 , 1.2359
# 0.0235 , 1.2400
# 0.0020 , 1.2380
# 0.0304 , 1.2417
# 0.1158 , 1.2340
# 3.4523 , 1.2381
# 0.3066 , 1.2385
# 3.2878 , 1.2491
# 0.6077 , 1.2540
# 0.0003 , 1.2519
# 0.9472 , 1.2496
# 0.5172 , 1.2599
# 0.1777 , 1.2581
# 0.2053 , 1.2492
# 0.6084 , 1.2520
# 0.5074 , 1.2574
# 1.8421 , 1.2447
# 0.5719 , 1.2520
# 0.0255 , 1.2413
# 0.3903 , 1.2447
# 0.6004 , 1.2482
# 0.3107 , 1.2535
# 0.0002 , 1.2446
# 0.5070 , 1.2514
# 0.3959 , 1.2460
# 1.5459 , 1.2443
# 0.8586 , 1.2493
# 0.1123 , 1.2454
# 0.8978 , 1.2466
# 0.5960 , 1.2444
# 0.1461 , 1.2430
# 5.9579 , 1.2435
# 0.2224 , 1.2422
# 0.0997 , 1.2386
# 0.0630 , 1.2461
# 0.3306 , 1.2446
# 2.5791 , 1.2414
# 0.0897 , 1.2417
# 0.4783 , 1.2326
# 6.9894 , 1.2356
# 0.0854 , 1.2310
# 0.4231 , 1.2355
# 0.2122 , 1.2387
# 2.5121 , 1.2341
# 0.0489 , 1.2297
# 0.8187 , 1.2311
# 0.2752 , 1.2294
# 0.2121 , 1.2366
# 0.1576 , 1.2368
# 4.0567 , 1.2323
# 0.8137 , 1.2306
# 0.6668 , 1.2334
# 0.0121 , 1.2328
# 0.3345 , 1.2337
# 0.1588 , 1.2281
# 0.0440 , 1.2274
# 1.0920 , 1.2339
# 0.0469 , 1.2370
# 3.2859 , 1.2244
# 0.0157 , 1.2268
# 2.3172 , 1.2316
# 2.1483 , 1.2299
# 0.2824 , 1.2253
# 0.0000 , 1.2348
# 0.0489 , 1.2297
# 0.0144 , 1.2256
# 0.6159 , 1.2297
# 0.0192 , 1.2306
# 0.2433 , 1.2257
# 0.2651 , 1.2268
# 1.3372 , 1.2305
# 0.2577 , 1.2365
# 0.8354 , 1.2318
# 0.1079 , 1.2289
# 0.0015 , 1.2355
# 0.8006 , 1.2296
# 0.1657 , 1.2389
# 0.2482 , 1.2254
# 2.8068 , 1.2357
# 0.4172 , 1.2276
# 0.0134 , 1.2314
# 0.0386 , 1.2292
# 3.6138 , 1.2263
# 1.7413 , 1.2301
# 0.2211 , 1.2364
# 0.0328 , 1.2403
# 0.4758 , 1.2266
# 0.2052 , 1.2266
# 3.3854 , 1.2301
# 0.1275 , 1.2206
# 19.4253 , 1.2238
# 0.0742 , 1.2363
# 0.0175 , 1.2308
# 1.6961 , 1.2322
# 0.0300 , 1.2383
# 0.0028 , 1.2223
# 0.0000 , 1.2282
# 0.7709 , 1.2216
# 0.0585 , 1.2214
# 0.0087 , 1.2267
# 0.0262 , 1.2201
# 0.0032 , 1.2292
# 0.0497 , 1.2268
# 0.1390 , 1.2314
# 2.9426 , 1.2180
# 0.3804 , 1.2301
# 3.3697 , 1.2354
# 0.6278 , 1.2474
# 0.0100 , 1.2480
# 0.9845 , 1.2445
# 0.5501 , 1.2440
# 0.1914 , 1.2438
# 0.2270 , 1.2343
# 0.6135 , 1.2444
# 0.4785 , 1.2407
# 1.7673 , 1.2362
# 0.6350 , 1.2406
# 0.0171 , 1.2278
# 0.2959 , 1.2244
# 0.3318 , 1.2355
# 0.3094 , 1.2342
# 0.0012 , 1.2313
# 0.5390 , 1.2402
# 0.3876 , 1.2307
# 1.3761 , 1.2326
# 0.9813 , 1.2329
# 0.1168 , 1.2342
# 0.7914 , 1.2296
# 0.6268 , 1.2292
# 0.1459 , 1.2344
# 5.7057 , 1.2300
# 0.1348 , 1.2287
# 0.1011 , 1.2251
# 0.0661 , 1.2274
# 0.3772 , 1.2281
# 2.3692 , 1.2188
# 0.0909 , 1.2284
# 0.4508 , 1.2296
# 6.8893 , 1.2254
# 0.0972 , 1.2156
# 0.3852 , 1.2272
# 0.1757 , 1.2243
# 2.5461 , 1.2257
# 0.0511 , 1.2174
# 0.8323 , 1.2191
# 0.2448 , 1.2190
# 0.2052 , 1.2283
# 0.1550 , 1.2218
# 4.2118 , 1.2256
# 0.8913 , 1.2143
# 0.6464 , 1.2185
# 0.0107 , 1.2182
# 0.2449 , 1.2133
# 0.1865 , 1.2151
# 0.0494 , 1.2093
# 1.0493 , 1.2140
# 0.0429 , 1.2170
# 3.0571 , 1.2156
# 0.0105 , 1.2168
# 2.3136 , 1.2267
# 1.9871 , 1.2169
# 0.2780 , 1.2125
# 0.0001 , 1.2149
# 0.0306 , 1.2098
# 0.0404 , 1.2210
# 0.6246 , 1.2100
# 0.0172 , 1.2132
# 0.2890 , 1.2134
# 0.2358 , 1.2183
# 1.2873 , 1.2160
# 0.2918 , 1.2179
# 0.7234 , 1.2203
# 0.0929 , 1.2139
# 0.0025 , 1.2207
# 0.7821 , 1.2139
# 0.0916 , 1.2224
# 0.1797 , 1.2113
# 2.8902 , 1.2193
# 0.4628 , 1.2164
# 0.0181 , 1.2112
# 0.0300 , 1.2179
# 3.6312 , 1.2166
# 2.1430 , 1.2095
# 0.1308 , 1.2150
# 0.1246 , 1.2180
# 0.3910 , 1.2089
# 0.1653 , 1.2255
# 3.5019 , 1.2156
# 0.1682 , 1.2137
# 18.6323 , 1.2079
# 0.0718 , 1.2112
# 0.0105 , 1.2096
# 1.7037 , 1.2215
# 0.0238 , 1.2247
# 0.0113 , 1.2103
# 0.0035 , 1.2130
# 0.8199 , 1.2144
# 0.0477 , 1.2061
# 0.0107 , 1.2086
# 0.0268 , 1.2112
# 0.0053 , 1.2084
# 0.0639 , 1.2132
# 0.1562 , 1.2109
# 2.5081 , 1.2032

# %%
csv_file = 'Losses_Model5_r=50_lambda=0.01_epoch10.csv'
save_losses_to_csv(loss_file5, csv_file)
# Out:
# file saved as:  Losses_Model5_r=50_lambda=0.01_epoch10.csv
